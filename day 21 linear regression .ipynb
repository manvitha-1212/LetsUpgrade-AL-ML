# %% [markdown]
# # House price prediction

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel("Linear Regression.xlsx", sheet_name=0)

# %%
data.head()
# Out:
#     price  sqft_living  bedrooms  bathrooms  floors
# 0  221900         1180         3       1.00     1.0
# 1  538000         2570         3       2.25     2.0
# 2  180000          770         2       1.00     1.0
# 3  604000         1960         4       3.00     1.0
# 4  510000         1680         3       2.00     1.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        21613 non-null  int64
#  1   sqft_living  21613 non-null  int64
#  2   bedrooms     21613 non-null  int64
#  3   bathrooms    21613 non-null  float64
#  4   floors       21613 non-null  float64
# dtypes: float64(2), int64(3)
# memory usage: 844.4 KB

# %%
data.shape
# Out:
# (21613, 5)

# %%
data.corr()
# Out:
#                 price  sqft_living  bedrooms  bathrooms    floors
# price        1.000000     0.702035  0.308350   0.525138  0.256794
# sqft_living  0.702035     1.000000  0.576671   0.754665  0.353949
# bedrooms     0.308350     0.576671  1.000000   0.515884  0.175429
# bathrooms    0.525138     0.754665  0.515884   1.000000  0.500653
# floors       0.256794     0.353949  0.175429   0.500653  1.000000

# %% [markdown]
# <p>All the independent variables like sqft_living , bedrooms , bathrooms , floors are positively correlated .</p>
# <p>price and sqft_living  are  strongly correlated as the value is .702 and is above .5  </p>
# <p>price and bedrooms are weakly correlated as the value is .308 whcih is lesser than .5 </p>
# <p>price and bathrooms are moderately correlated as the value is .525 which is almost near to .5</p>
# <p>price and floor are weakly correlated a sthe value is .256 which is lesser than .5  </p>

# %%
sns.pairplot(data)

# %%
data.hist(figsize=(14,12), bins=50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000026028DCDB48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026028DEB348>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000260291F4C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002602923D348>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002602924B448>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000026028F51508>]],
#       dtype=object)

# %%
data.isnull().sum()
# Out:
# price          0
# sqft_living    0
# bedrooms       0
# bathrooms      0
# floors         0
# dtype: int64

# %%
data.describe()
# Out:
#               price   sqft_living      bedrooms     bathrooms        floors
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   5.400881e+05   2079.899736      3.370842      2.114757      1.494309
# std    3.671272e+05    918.440897      0.930062      0.770163      0.539989
# min    7.500000e+04    290.000000      0.000000      0.000000      1.000000
# 25%    3.219500e+05   1427.000000      3.000000      1.750000      1.000000
# 50%    4.500000e+05   1910.000000      3.000000      2.250000      1.500000
# 75%    6.450000e+05   2550.000000      4.000000      2.500000      2.000000
# max    7.700000e+06  13540.000000     33.000000      8.000000      3.500000

# %%
x = data.drop(['price'], axis=1)
y = data.iloc[:,:1]

# %%
from sklearn.model_selection import train_test_split

# %%
train_x,test_x,train_y,test_y = train_test_split(x,y,random_state = 0,test_size=0.20)

# %%
train_x.shape, train_y.shape
# Out:
# ((17290, 4), (17290, 1))

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(train_x, train_y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
ypred = lr.predict(test_x)

# %%
from sklearn.metrics import r2_score,mean_squared_error,accuracy_score
print(f"R-Square score is {r2_score(test_y, ypred)}")
print(f"RMSE is {np.sqrt(mean_squared_error(test_y, ypred))}")
# Out:
# R-Square score is 0.49571065104477097
# RMSE is 244892.30412806544

# %%
print(f"R-Square score is {r2_score(train_y, lr.predict(train_x))}")
# Out:
# R-Square score is 0.5090292992594028

# %%
import statsmodels.api as sm
lm = sm.OLS(train_y, train_x)
lm1 = lm.fit()

# %%
x.head()
# Out:
#    sqft_living  bedrooms  bathrooms  floors
# 0         1180         3       1.00     1.0
# 1         2570         3       2.25     2.0
# 2          770         2       1.00     1.0
# 3         1960         4       3.00     1.0
# 4         1680         3       2.00     1.0

# %%
lm1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                  price   R-squared (uncentered):                   0.844
# Model:                            OLS   Adj. R-squared (uncentered):              0.844
# Method:                 Least Squares   F-statistic:                          2.197e+04
# Date:                Sat, 08 Aug 2020   Prob (F-statistic):                        0.00
# Time:                        18:40:53   Log-Likelihood:                     -2.2500e+05
# No. Observations:               16209   AIC:                                  4.500e+05
# Df Residuals:                   16205   BIC:                                  4.500e+05
# Df Model:                           4
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# sqft_living   307.0220      3.511     87.448      0.000     300.140     313.904
# bedrooms    -4.059e+04   2072.754    -19.583      0.000   -4.47e+04   -3.65e+04
# bathrooms    4491.1002   4387.460      1.024      0.306   -4108.805    1.31e+04
# floors       1.752e+04   3904.181      4.488      0.000    9869.010    2.52e+04
# ==============================================================================
# Omnibus:                    10393.497   Durbin-Watson:                   2.014
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           335133.798
# Skew:                           2.588   Prob(JB):                         0.00
# Kurtosis:                      24.666   Cond. No.                     5.69e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.69e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# # Price Vs Bathrooms

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_excel("Linear Regression.xlsx",sheet_name=0)

# %%
data.head()
# Out:
#     price  sqft_living  bedrooms  bathrooms  floors
# 0  221900         1180         3       1.00     1.0
# 1  538000         2570         3       2.25     2.0
# 2  180000          770         2       1.00     1.0
# 3  604000         1960         4       3.00     1.0
# 4  510000         1680         3       2.00     1.0

# %%
x = data.drop(['price','sqft_living','bedrooms','floors'], axis=1)
y = data.drop(['sqft_living','bedrooms','bathrooms','floors'], axis=1)

# %%
from sklearn.model_selection import train_test_split
train_x,test_x,train_y,test_y = train_test_split(x,y,random_state = 42,test_size=0.20)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(train_x, train_y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
plt.scatter(train_x, train_y, color = 'yellow')
plt.plot(train_x, lr.predict(train_x), color = 'black')
plt.show()

# %%
ypred = lr.predict(test_x)

# %%
from sklearn.metrics import r2_score
print(r2_score(test_y, ypred))
# Out:
# 0.269644635933329

# %%
plt.scatter(test_x, test_y, color = 'yellow')
plt.plot(test_x, lr.predict(test_x), color = 'black')
plt.show()

# %% [markdown]
# # Price Vs Sq.foot

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel("Linear Regression.xlsx",sheet_name=0)

# %%
data.head()
# Out:
#     price  sqft_living  bedrooms  bathrooms  floors
# 0  221900         1180         3       1.00     1.0
# 1  538000         2570         3       2.25     2.0
# 2  180000          770         2       1.00     1.0
# 3  604000         1960         4       3.00     1.0
# 4  510000         1680         3       2.00     1.0

# %%
x = data.drop(['price','bedrooms','bathrooms','floors'], axis=1)
y = data.drop(['sqft_living','bedrooms','bathrooms','floors'], axis=1)

# %%
from sklearn.model_selection import train_test_split
train_x,test_x,train_y,test_y = train_test_split(x,y,random_state = 42,test_size=0.20)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(train_x, train_y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
plt.scatter(train_x, train_y, color = 'yellow')
plt.plot(train_x, lr.predict(train_x), color = 'black')
plt.show()

# %%
ypred = lr.predict(test_x)

# %%
from sklearn.metrics import r2_score
print(r2_score(test_y, ypred))
# Out:
# 0.4940690470123985

# %%
plt.scatter(test_x, test_y, color = 'yellow')
plt.plot(test_x, lr.predict(test_x), color = 'black')
plt.show()

# %% [markdown]
# # Price Vs Bedrooms

# %%
x = data.drop(['price','sqft_living','bathrooms','floors'], axis=1)

y = data.drop(['sqft_living','bedrooms','bathrooms','floors'], axis=1)

# %%
from sklearn.model_selection import train_test_split
train_x,test_x,train_y,test_y = train_test_split(x,y,random_state = 42,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(train_x, train_y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
plt.scatter(train_x, train_y, color = 'yellow')
plt.plot(train_x, lr.predict(train_x), color = 'black')
plt.show()

# %%
ypred = lr.predict(test_x)

# %%
from sklearn.metrics import r2_score
print(r2_score(test_y, ypred))
# Out:
# 0.09436575288410964

# %%
plt.scatter(test_x, test_y, color = 'yellow')
plt.plot(test_x, lr.predict(test_x), color = 'black')
plt.show()

# %% [markdown]
# # Price Vs Floor

# %%
x = data.drop(['price','sqft_living','bedrooms','bathrooms'], axis=1)
y = data.drop(['sqft_living','bedrooms','bathrooms','floors'], axis=1)

# %%
from sklearn.model_selection import train_test_split
train_x,test_x,train_y,test_y = train_test_split(x,y,random_state = 42,test_size=0.20)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(train_x, train_y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
plt.scatter(train_x, train_y, color = 'yellow')
plt.plot(train_x, lr.predict(train_x), color = 'black')
plt.show()

# %%
ypred = lr.predict(test_x)

# %%
from sklearn.metrics import r2_score
print(r2_score(test_y, ypred))
# Out:
# 0.070565432514475

# %%
plt.scatter(test_x, test_y, color = 'yellow')
plt.plot(test_x, lr.predict(test_x), color = 'black')
plt.show()
